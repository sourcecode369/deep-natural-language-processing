# %% [markdown]
# <a href="https://colab.research.google.com/github/sourcecode369/deep-nlp/blob/master/sequence%20classification/Long_Short_Term_Memory_Sequence_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
import numpy as np
from numpy import array
from tensorflow.keras.models import load_model
# Out:
# TensorFlow 2.x selected.

# %%
def get_train():
  seq = [[np.round(i*0.1,1),np.round(i*0.1+.1,1)] for i in range(1000)]
  seq = np.array(seq)
  X, y = seq[:,0], seq[:,1]
  X = X.reshape((len(X),1,1))
  return X, y

# %%
X, y = get_train()

# %%
def build_model():
  model = Sequential([
                      LSTM(20,return_sequences=True,input_shape=(1,1)),
                      Dense(1, activation='linear')
  ])
  return model

opt = tf.keras.optimizers.Adam()

model = build_model()

# %%
model.compile(optimizer=opt,loss='mse')

# %%
model.fit(X,y,shuffle=False, epochs=500, verbose=1,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss',patience=10,verbose=1)])
# Out:
# Train on 1000 samples
# Epoch 1/500
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 3364.8626
# Epoch 2/500
# 1000/1000 [==============================] - 0s 115us/sample - loss: 3322.3476
# Epoch 3/500
# 1000/1000 [==============================] - 0s 112us/sample - loss: 3262.5053
# Epoch 4/500
# 1000/1000 [==============================] - 0s 116us/sample - loss: 3216.4533
# Epoch 5/500
# 1000/1000 [==============================] - 0s 107us/sample - loss: 3141.2909
# Epoch 6/500
# 1000/1000 [==============================] - 0s 110us/sample - loss: 3100.3567
# Epoch 7/500
# 1000/1000 [==============================] - 0s 107us/sample - loss: 3053.0430
# Epoch 8/500
# 1000/1000 [==============================] - 0s 129us/sample - loss: 3006.6946
# Epoch 9/500
# 1000/1000 [==============================] - 0s 129us/sample - loss: 2966.1011
# Epoch 10/500
# 1000/1000 [==============================] - 0s 119us/sample - loss: 2933.7376
# Epoch 11/500
# ...

# %%
yhat = model.predict(X,verbose=1)
# Out:
# 1000/1000 [==============================] - 0s 311us/sample
